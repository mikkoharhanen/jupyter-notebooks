# %% [markdown]
# # Data-analyysi levyraadin tuloksista
#
# Esittelen tässä Jupyter-muistiossa Python-ohjelmointikielen data-analyysityökaluja. Muistion esimerkit pohjautuvat Facebook-ryhmässä järjestettyyn musiikkikilpailuun, joka on mukailtu televisio-ohjelmasta Levyraati.
#
# ### Analyysissä käytetyt menetelmät:
# - laatikkodiagrammi, joka sisältää kvartiilit ja mediaanin
# - keskihajonta
# - aineiston normalisointi
# - euklidisen etäisyyden mittaaminen
# - pääkomponenttianalyysi
#
# ### Aineisto
# Aineisto on kerätty Facebook-ryhmästä keväällä 2016. Mukana olleet raatilaiset ovat arvostelleet jokaisen kappaleen, kirjoittaneen sanallisen arvioinnin sekä antaneet numeerisen arvosanan. Tässä analyysissä hyödynnän vain arvosanoja.
# - 10 kappaletta
# - 7 arvostelijaa
# - arvosanat asteikolla 0,5 - 5

# %% [markdown]
# ## Hae aineisto

# %%
# Data-analyysin perustyökalut
import numpy as np
import pandas as pd

# %%
# Kuvaajat
# %matplotlib inline
import seaborn as sns
sns.set_style("whitegrid")

# %%
df = pd.read_csv('levyraati-2016.csv', index_col=0, decimal=',')
df
# Out:
#                                                     Sami   Joe  Mikko  Taneli  \
# Kappale
# Tungevaag & Raaban – Parade                         4.50  0.50      3       2
# Asa – Mä haluun olla hippi                          1.00  2.25      4       1
# Chubby Wolf – You are the Description that brin...  0.50  1.00      1       3
# Supperheads – Easy                                  2.00  2.75      5       3
# Dream Theater – The Silent Man                      2.25  2.25      1       3
# Tony Bennett & Lady Gaga – It Don't Mean a Thing    3.00  1.25      3       3
# Elina Born – Miss Calculation                       2.00  2.50      4       4
# Caravan Palace – Lone Digger                        0.50  2.50      5       5
# Avril Lavigne – When You're Gone                    4.50  2.75      2       3
# Halestorm – Here's to US                            3.50  4.00      4       4
#
#                                                     Arttu  Ville  Kirmo
# Kappale
# Tungevaag & Raaban – Parade                           2.0   2.00   4.50
# Asa – Mä haluun olla hippi                            2.0   2.00   2.50
# Chubby Wolf – You are the Description that brin...    4.0   1.00   2.00
# Supperheads – Easy                                    2.0   5.00   3.50
# Dream Theater – The Silent Man                        2.5   4.50   3.75
# Tony Bennett & Lady Gaga – It Don't Mean a Thing      4.0   1.50   4.00
# Elina Born – Miss Calculation                         1.0   3.00   3.75
# Caravan Palace – Lone Digger                          4.0   1.75   4.75
# Avril Lavigne – When You're Gone                      1.0   3.75   4.25
# Halestorm – Here's to US                              0.5   3.50   4.00

# %% [markdown]
# # Analysoi musiikkikappaleet

# %% [markdown]
# ## Mikä kappale voitti levyraadin?
# Levyraadin voittaa eniten pisteitä kerännyt kilpailija. Raadissamme oli kaksi tasavertaista kappaletta: *Here's to US* ja *Lone Digger*.

# %%
df.sum(axis=1).sort_values().plot(kind = 'barh', title = 'Yhteenlasketut pisteet suurimmasta pienimpään')

# %% [markdown]
# ## Oliko raati arvosteluissaan yksimielinen?

# %% [markdown]
# Seuraavaksi selvitän, kuinka yksimielisesti raati äänesti. Aloitan piirtämällä laatikkodiagrammin, joka paljastaa kappaleiden yksittäiset arvosanat, vaihteluvälin, mediaanin sekä ylä- ja alaneljänneksen.
#
# Voin nähdä kuvioista, että kappaleiden pisteytyksessä on suurta vaihtelua. Tämä viittaa siihen, että raati ei ole arvostelussaan yksimielinen. Lisäksi huomaan, että tiettyjen kappaleiden laatikot ovat muita pidempiä, eli nämä kappaleet saavat ristiriitaisia arvosteluja.

# %%
ax = sns.boxplot(data=df.T, orient='h')
ax = sns.swarmplot(data=df.T, orient='h', color='black')
ax.set_title('Kappaleiden arvosanajakauma')

# %% [markdown]
# Pystyn jo kuvaa katsomalla arvailla, mikä kappaleista on saanut ristiriitaisimman vastaanoton, mutta haluan todeta asian laskennallisesti. Käytän tarkoitukseeni standardipoikkeamaa eli keskimääräistä poikkeamaa odotusarvosta.
# $$D(X)=\sigma_x = \sqrt{\sigma^{2}_x}$$
#
# Kappaleen *Lone Digger* arvosanat poikkeavat 1,8 pistettä odotusarvosta. Levyraadin ääniharava on myös kierroksen ristiriitaisin kappale. Pienin keskihajonta on Asan kappaleella *Mä haluun olla hippi*, eli tuomaristo on yksimielisesti pitänyt sita raadin heikoimpiin kuuluvana esityksenä.

# %%
pd.DataFrame(df.std(axis=1).sort_values(ascending=False), columns=['Keskihajonta'])
# Out:
#                                                     Keskihajonta
# Kappale
# Caravan Palace – Lone Digger                            1.790351
# Tungevaag & Raaban – Parade                             1.463850
# Chubby Wolf – You are the Description that brin...      1.286375
# Halestorm – Here's to US                                1.281740
# Supperheads – Easy                                      1.264205
# Avril Lavigne – When You're Gone                        1.253566
# Dream Theater – The Silent Man                          1.136515
# Elina Born – Miss Calculation                           1.135205
# Tony Bennett & Lady Gaga – It Don't Mean a Thing        1.086990
# Asa – Mä haluun olla hippi                              1.019162

# %% [markdown]
# # Analysoi arvostelijat

# %% [markdown]
# ## Kuka on avokätisin raatilainen?
# Edellisessä tarkastelussa huomasin, että sama kappale saa vaihtelevia pisteitä eri arvostelijoilta. Seuraavaksi haluan selvittää, miten raadit jäsenet eroavat toisistaan. Aloitan laskemalla, mitä raatilaiset antavat keskimäärin arvosanaksi kappaleille.

# %%
df.mean().sort_values().plot(kind='barh')

# %% [markdown]
# Keskiarvoista näkee, että Kirmo on antaa keskimäärin parhaimmat pisteet ja Joe huonoimmat. Ero voi johtua siitä, että Kirmo piti tämän kierroksen kappaleista enemmän kuin Joe tai sitten he käyttävät arvosteluasteikkoa eri tavalla.

# %% [markdown]
# ## Normalisoi arvosanat
#
# Arvosana 3 voi olla yhdelle jäsenelle hyvä ja toiselle huono. Tuomaristo käyttää arvosteluasteikkoa eri tavoin, joten pisteet eivät välttämättä ole vertailukelpoisia. Haluan, että lukuja on helppo vertailla keskenään, joten normalisoin luvut. Normalisoinnin jälkeen jälkeen arvosanat ovat nollan ja yhden välillä.
#
# $$X' = \frac{X - X_{min}}{X_{max} - X_{min}}$$

# %%
# Määritellään kaavan mukainen normalisointifunktio
def normalize_values(x):
    return( (x - x.min()) / (x.max() - x.min()) )

# %%
df_norm = df.apply(normalize_values)
df_norm
# Out:
#                                                       Sami       Joe  Mikko  \
# Kappale
# Tungevaag & Raaban – Parade                         1.0000  0.000000   0.50
# Asa – Mä haluun olla hippi                          0.1250  0.500000   0.75
# Chubby Wolf – You are the Description that brin...  0.0000  0.142857   0.00
# Supperheads – Easy                                  0.3750  0.642857   1.00
# Dream Theater – The Silent Man                      0.4375  0.500000   0.00
# Tony Bennett & Lady Gaga – It Don't Mean a Thing    0.6250  0.214286   0.50
# Elina Born – Miss Calculation                       0.3750  0.571429   0.75
# Caravan Palace – Lone Digger                        0.0000  0.571429   1.00
# Avril Lavigne – When You're Gone                    1.0000  0.642857   0.25
# Halestorm – Here's to US                            0.7500  1.000000   0.75
#
#                                                     Taneli     Arttu   Ville  \
# Kappale
# Tungevaag & Raaban – Parade                           0.25  0.428571  0.2500
# Asa – Mä haluun olla hippi                            0.00  0.428571  0.2500
# Chubby Wolf – You are the Description that brin...    0.50  1.000000  0.0000
# Supperheads – Easy                                    0.50  0.428571  1.0000
# Dream Theater – The Silent Man                        0.50  0.571429  0.8750
# Tony Bennett & Lady Gaga – It Don't Mean a Thing      0.50  1.000000  0.1250
# Elina Born – Miss Calculation                         0.75  0.142857  0.5000
# Caravan Palace – Lone Digger                          1.00  1.000000  0.1875
# Avril Lavigne – When You're Gone                      0.50  0.142857  0.6875
# Halestorm – Here's to US                              0.75  0.000000  0.6250
#
#                                                        Kirmo
# Kappale
# Tungevaag & Raaban – Parade                         0.909091
# Asa – Mä haluun olla hippi                          0.181818
# Chubby Wolf – You are the Description that brin...  0.000000
# Supperheads – Easy                                  0.545455
# Dream Theater – The Silent Man                      0.636364
# Tony Bennett & Lady Gaga – It Don't Mean a Thing    0.727273
# Elina Born – Miss Calculation                       0.636364
# Caravan Palace – Lone Digger                        1.000000
# Avril Lavigne – When You're Gone                    0.818182
# Halestorm – Here's to US                            0.727273

# %% [markdown]
# Normalisoinnin jälkeen laskemme voittajan uudelleen. Jos kaikki raatilaiset olisivat käyttäneet arvosteluasteikkoa yhtä laajasti, niin kilpailun olisi voittanut kappale *Lone Digger*.

# %%
df_norm.T.sum().sort_values().plot(kind='barh')

# %% [markdown]
# ## Ketkä arvostelijat ovat samankaltaisia?

# %% [markdown]
# Levyraadin pistetaulukko kuvastaa raatilaisten mieltymyksiä, joten voin selvittää kenen musiikkimaku on lähimpänä omaani. Aion verrata yksitellen jokaisen raatilaisen antamia pisteitä omiini ja katsoa, kuinka paljon pisteissä on eroa. Raatilainen, jonka pisteissä on vähiten eroa omiini, on mahdollisesti musiikkimaultaan samantyylinen kuin minä.
#
# Kahden tasolla olevan pisteen etäisyyden voi laskea Pythagoraan lauseella. Samaa menettelyä voi soveltaa myös moniulotteisemmissa avaruuksissa. Menetelmän nimi on euklidinen mittaus:
#
# $$ \mathrm{d}(\mathbf{p},\mathbf{q}) = \sqrt{\sum_{i=1}^n (q_i-p_i)^2} $$
#
# Raatimme arvosteli 10 kappaletta, joten arvioin yhden raatilaisen etäisyyden toiseen raatilaiseen 10 kappaleen perusteella. Sovellamme siis euklidista mittausta 10-ulotteisessa avaruudessa.

# %%
# Numpy-moodulin funktio linalg.norm, laskee euklidisen etäisyyden kahden vektorin välillä.
# Haluan verrata datataulun jokaista saraketta jokaiseen sarakkeeseen, joten luon silmukka-
# rakenteen kahdella sisäkkäisellä lamda-funktiolla.

D = df_norm.apply(lambda c1: df_norm.apply(lambda c2: np.linalg.norm(c1 - c2)))

# Ei verrata raatilaisen musiikkimakua häneen itseensä <-- arvoksi NaN
np.fill_diagonal(D.values, np.nan)
D.style.background_gradient()
# Out:
#         <style  type="text/css" >
#
#
#             #T_91eba5f4_4470_11e6_aa9a_f0def1ce0ecbrow0_col0 {
#
#                 background-color:  #fff7fb;
#
#             }
#
#             #T_91eba5f4_4470_11e6_aa9a_f0def1ce0ecbrow0_col1 {
#
#                 background-color:  #4897c4;
#
#             }
#
#             #T_91eba5f4_4470_11e6_aa9a_f0def1ce0ecbrow0_col2 {
#
#                 background-color:  #02395a;
#
#             }
#
#             #T_91eba5f4_4470_11e6_aa9a_f0def1ce0ecbrow0_col3 {
#
#                 background-color:  #023858;
#
#             }
#
#             #T_91eba5f4_4470_11e6_aa9a_f0def1ce0ecbrow0_col4 {
#
#                 background-color:  #023858;
#
#             }
#
#             #T_91eba5f4_4470_11e6_aa9a_f0def1ce0ecbrow0_col5 {
#
#                 background-color:  #a5bddb;
#
#             }
#
#             #T_91eba5f4_4470_11e6_aa9a_f0def1ce0ecbrow0_col6 {
#
#                 background-color:  #d9d8ea;
#
#             }
#
#             #T_91eba5f4_4470_11e6_aa9a_f0def1ce0ecbrow1_col0 {
#
#                 background-color:  #b0c2de;
#
#             }
#
#             #T_91eba5f4_4470_11e6_aa9a_f0def1ce0ecbrow1_col1 {
#
#                 background-color:  #fff7fb;
#
#             }
#
#             #T_91eba5f4_4470_11e6_aa9a_f0def1ce0ecbrow1_col2 {
#
#                 background-color:  #fff7fb;
#
#             }
#
#             #T_91eba5f4_4470_11e6_aa9a_f0def1ce0ecbrow1_col3 {
#
#                 background-color:  #fff7fb;
#
#             }
#
#             #T_91eba5f4_4470_11e6_aa9a_f0def1ce0ecbrow1_col4 {
#
#                 background-color:  #167bb6;
#
#             }
#
#             #T_91eba5f4_4470_11e6_aa9a_f0def1ce0ecbrow1_col5 {
#
#                 background-color:  #fff7fb;
#
#             }
#
#             #T_91eba5f4_4470_11e6_aa9a_f0def1ce0ecbrow1_col6 {
#
#                 background-color:  #8fb4d6;
#
#             }
#
#             #T_91eba5f4_4470_11e6_aa9a_f0def1ce0ecbrow2_col0 {
#
#                 background-color:  #187cb6;
#
#             }
#
#             #T_91eba5f4_4470_11e6_aa9a_f0def1ce0ecbrow2_col1 {
#
#                 background-color:  #c8cde4;
#
#             }
#
#             #T_91eba5f4_4470_11e6_aa9a_f0def1ce0ecbrow2_col2 {
#
#                 background-color:  #fff7fb;
#
#             }
#
#             #T_91eba5f4_4470_11e6_aa9a_f0def1ce0ecbrow2_col3 {
#
#                 background-color:  #7bacd1;
#
#             }
#
#             #T_91eba5f4_4470_11e6_aa9a_f0def1ce0ecbrow2_col4 {
#
#                 background-color:  #4697c4;
#
#             }
#
#             #T_91eba5f4_4470_11e6_aa9a_f0def1ce0ecbrow2_col5 {
#
#                 background-color:  #509ac6;
#
#             }
#
#             #T_91eba5f4_4470_11e6_aa9a_f0def1ce0ecbrow2_col6 {
#
#                 background-color:  #9ab8d8;
#
#             }
#
#             #T_91eba5f4_4470_11e6_aa9a_f0def1ce0ecbrow3_col0 {
#
#                 background-color:  #84b0d3;
#
#             }
#
#             #T_91eba5f4_4470_11e6_aa9a_f0def1ce0ecbrow3_col1 {
#
#                 background-color:  #f4edf6;
#
#             }
#
#             #T_91eba5f4_4470_11e6_aa9a_f0def1ce0ecbrow3_col2 {
#
#                 background-color:  #e7e3f0;
#
#             }
#
#             #T_91eba5f4_4470_11e6_aa9a_f0def1ce0ecbrow3_col3 {
#
#                 background-color:  #fff7fb;
#
#             }
#
#             #T_91eba5f4_4470_11e6_aa9a_f0def1ce0ecbrow3_col4 {
#
#                 background-color:  #fff7fb;
#
#             }
#
#             #T_91eba5f4_4470_11e6_aa9a_f0def1ce0ecbrow3_col5 {
#
#                 background-color:  #9fbad9;
#
#             }
#
#             #T_91eba5f4_4470_11e6_aa9a_f0def1ce0ecbrow3_col6 {
#
#                 background-color:  #fff7fb;
#
#             }
#
#             #T_91eba5f4_4470_11e6_aa9a_f0def1ce0ecbrow4_col0 {
#
#                 background-color:  #023858;
#
#             }
#
#             #T_91eba5f4_4470_11e6_aa9a_f0def1ce0ecbrow4_col1 {
#
#                 background-color:  #023858;
#
#             }
#
#             #T_91eba5f4_4470_11e6_aa9a_f0def1ce0ecbrow4_col2 {
#
#                 background-color:  #023858;
#
#             }
#
#             #T_91eba5f4_4470_11e6_aa9a_f0def1ce0ecbrow4_col3 {
#
#                 background-color:  #1278b4;
#
#             }
#
#             #T_91eba5f4_4470_11e6_aa9a_f0def1ce0ecbrow4_col4 {
#
#                 background-color:  #fff7fb;
#
#             }
#
#             #T_91eba5f4_4470_11e6_aa9a_f0def1ce0ecbrow4_col5 {
#
#                 background-color:  #023858;
#
#             }
#
#             #T_91eba5f4_4470_11e6_aa9a_f0def1ce0ecbrow4_col6 {
#
#                 background-color:  #023858;
#
#             }
#
#             #T_91eba5f4_4470_11e6_aa9a_f0def1ce0ecbrow5_col0 {
#
#                 background-color:  #e0dded;
#
#             }
#
#             #T_91eba5f4_4470_11e6_aa9a_f0def1ce0ecbrow5_col1 {
#
#                 background-color:  #fff7fb;
#
#             }
#
#             #T_91eba5f4_4470_11e6_aa9a_f0def1ce0ecbrow5_col2 {
#
#                 background-color:  #4897c4;
#
#             }
#
#             #T_91eba5f4_4470_11e6_aa9a_f0def1ce0ecbrow5_col3 {
#
#                 background-color:  #3f93c2;
#
#             }
#
#             #T_91eba5f4_4470_11e6_aa9a_f0def1ce0ecbrow5_col4 {
#
#                 background-color:  #034e7b;
#
#             }
#
#             #T_91eba5f4_4470_11e6_aa9a_f0def1ce0ecbrow5_col5 {
#
#                 background-color:  #fff7fb;
#
#             }
#
#             #T_91eba5f4_4470_11e6_aa9a_f0def1ce0ecbrow5_col6 {
#
#                 background-color:  #509ac6;
#
#             }
#
#             #T_91eba5f4_4470_11e6_aa9a_f0def1ce0ecbrow6_col0 {
#
#                 background-color:  #fff7fb;
#
#             }
#
#             #T_91eba5f4_4470_11e6_aa9a_f0def1ce0ecbrow6_col1 {
#
#                 background-color:  #96b6d7;
#
#             }
#
#             #T_91eba5f4_4470_11e6_aa9a_f0def1ce0ecbrow6_col2 {
#
#                 background-color:  #dfddec;
#
#             }
#
#             #T_91eba5f4_4470_11e6_aa9a_f0def1ce0ecbrow6_col3 {
#
#                 background-color:  #f7f0f7;
#
#             }
#
#             #T_91eba5f4_4470_11e6_aa9a_f0def1ce0ecbrow6_col4 {
#
#                 background-color:  #8eb3d5;
#
#             }
#
#             #T_91eba5f4_4470_11e6_aa9a_f0def1ce0ecbrow6_col5 {
#
#                 background-color:  #89b1d4;
#
#             }
#
#             #T_91eba5f4_4470_11e6_aa9a_f0def1ce0ecbrow6_col6 {
#
#                 background-color:  #fff7fb;
#
#             }
#
#         </style>
#
#         <table id="T_91eba5f4_4470_11e6_aa9a_f0def1ce0ecb" None>
#
#
#         <thead>
#
#             <tr>
#
#                 <th class="blank">
#
#                 <th class="col_heading level0 col0">Sami
#
#                 <th c

# %% [markdown]
# Kahden nimen risteyskohta kertoo raatilaisten etäisyyden toisistaan. Suuri luku tarkoittaa suurta eroa annetuissa arvosanoissa. Huomaan, että nimeni sarakkeella pienin arvo on Joen kohdalla (1,10657), eli hänen musiikkimakunsa eroaa vähiten omastani. Vähiten samanlainen musiikkimaku minulla on Artun kanssa (1,71874).
#
# Yritän tehdä taulukosta helppolukuisemman korvaamalla euklidisen etäisyyden sijoitusnumerolla. Toisin sanoen haluan nähdä helposti, kenen musiikkimaku on minua ensimmäiseksi, toiseksi ja kolmanneksi lähimpänä.

# %%
D.rank().style.background_gradient()
# Out:
#         <style  type="text/css" >
#
#
#             #T_91f44c68_4470_11e6_aa9a_f0def1ce0ecbrow0_col0 {
#
#                 background-color:  #fff7fb;
#
#             }
#
#             #T_91f44c68_4470_11e6_aa9a_f0def1ce0ecbrow0_col1 {
#
#                 background-color:  #0567a2;
#
#             }
#
#             #T_91f44c68_4470_11e6_aa9a_f0def1ce0ecbrow0_col2 {
#
#                 background-color:  #0567a2;
#
#             }
#
#             #T_91f44c68_4470_11e6_aa9a_f0def1ce0ecbrow0_col3 {
#
#                 background-color:  #023858;
#
#             }
#
#             #T_91f44c68_4470_11e6_aa9a_f0def1ce0ecbrow0_col4 {
#
#                 background-color:  #023858;
#
#             }
#
#             #T_91f44c68_4470_11e6_aa9a_f0def1ce0ecbrow0_col5 {
#
#                 background-color:  #dbdaeb;
#
#             }
#
#             #T_91f44c68_4470_11e6_aa9a_f0def1ce0ecbrow0_col6 {
#
#                 background-color:  #dbdaeb;
#
#             }
#
#             #T_91f44c68_4470_11e6_aa9a_f0def1ce0ecbrow1_col0 {
#
#                 background-color:  #9cb9d9;
#
#             }
#
#             #T_91f44c68_4470_11e6_aa9a_f0def1ce0ecbrow1_col1 {
#
#                 background-color:  #fff7fb;
#
#             }
#
#             #T_91f44c68_4470_11e6_aa9a_f0def1ce0ecbrow1_col2 {
#
#                 background-color:  #fff7fb;
#
#             }
#
#             #T_91f44c68_4470_11e6_aa9a_f0def1ce0ecbrow1_col3 {
#
#                 background-color:  #fff7fb;
#
#             }
#
#             #T_91f44c68_4470_11e6_aa9a_f0def1ce0ecbrow1_col4 {
#
#                 background-color:  #4295c3;
#
#             }
#
#             #T_91f44c68_4470_11e6_aa9a_f0def1ce0ecbrow1_col5 {
#
#                 background-color:  #fff7fb;
#
#             }
#
#             #T_91f44c68_4470_11e6_aa9a_f0def1ce0ecbrow1_col6 {
#
#                 background-color:  #4295c3;
#
#             }
#
#             #T_91f44c68_4470_11e6_aa9a_f0def1ce0ecbrow2_col0 {
#
#                 background-color:  #0567a2;
#
#             }
#
#             #T_91f44c68_4470_11e6_aa9a_f0def1ce0ecbrow2_col1 {
#
#                 background-color:  #9cb9d9;
#
#             }
#
#             #T_91f44c68_4470_11e6_aa9a_f0def1ce0ecbrow2_col2 {
#
#                 background-color:  #fff7fb;
#
#             }
#
#             #T_91f44c68_4470_11e6_aa9a_f0def1ce0ecbrow2_col3 {
#
#                 background-color:  #9cb9d9;
#
#             }
#
#             #T_91f44c68_4470_11e6_aa9a_f0def1ce0ecbrow2_col4 {
#
#                 background-color:  #9cb9d9;
#
#             }
#
#             #T_91f44c68_4470_11e6_aa9a_f0def1ce0ecbrow2_col5 {
#
#                 background-color:  #0567a2;
#
#             }
#
#             #T_91f44c68_4470_11e6_aa9a_f0def1ce0ecbrow2_col6 {
#
#                 background-color:  #9cb9d9;
#
#             }
#
#             #T_91f44c68_4470_11e6_aa9a_f0def1ce0ecbrow3_col0 {
#
#                 background-color:  #4295c3;
#
#             }
#
#             #T_91f44c68_4470_11e6_aa9a_f0def1ce0ecbrow3_col1 {
#
#                 background-color:  #dbdaeb;
#
#             }
#
#             #T_91f44c68_4470_11e6_aa9a_f0def1ce0ecbrow3_col2 {
#
#                 background-color:  #dbdaeb;
#
#             }
#
#             #T_91f44c68_4470_11e6_aa9a_f0def1ce0ecbrow3_col3 {
#
#                 background-color:  #fff7fb;
#
#             }
#
#             #T_91f44c68_4470_11e6_aa9a_f0def1ce0ecbrow3_col4 {
#
#                 background-color:  #fff7fb;
#
#             }
#
#             #T_91f44c68_4470_11e6_aa9a_f0def1ce0ecbrow3_col5 {
#
#                 background-color:  #9cb9d9;
#
#             }
#
#             #T_91f44c68_4470_11e6_aa9a_f0def1ce0ecbrow3_col6 {
#
#                 background-color:  #fff7fb;
#
#             }
#
#             #T_91f44c68_4470_11e6_aa9a_f0def1ce0ecbrow4_col0 {
#
#                 background-color:  #023858;
#
#             }
#
#             #T_91f44c68_4470_11e6_aa9a_f0def1ce0ecbrow4_col1 {
#
#                 background-color:  #023858;
#
#             }
#
#             #T_91f44c68_4470_11e6_aa9a_f0def1ce0ecbrow4_col2 {
#
#                 background-color:  #023858;
#
#             }
#
#             #T_91f44c68_4470_11e6_aa9a_f0def1ce0ecbrow4_col3 {
#
#                 background-color:  #0567a2;
#
#             }
#
#             #T_91f44c68_4470_11e6_aa9a_f0def1ce0ecbrow4_col4 {
#
#                 background-color:  #fff7fb;
#
#             }
#
#             #T_91f44c68_4470_11e6_aa9a_f0def1ce0ecbrow4_col5 {
#
#                 background-color:  #023858;
#
#             }
#
#             #T_91f44c68_4470_11e6_aa9a_f0def1ce0ecbrow4_col6 {
#
#                 background-color:  #023858;
#
#             }
#
#             #T_91f44c68_4470_11e6_aa9a_f0def1ce0ecbrow5_col0 {
#
#                 background-color:  #dbdaeb;
#
#             }
#
#             #T_91f44c68_4470_11e6_aa9a_f0def1ce0ecbrow5_col1 {
#
#                 background-color:  #fff7fb;
#
#             }
#
#             #T_91f44c68_4470_11e6_aa9a_f0def1ce0ecbrow5_col2 {
#
#                 background-color:  #4295c3;
#
#             }
#
#             #T_91f44c68_4470_11e6_aa9a_f0def1ce0ecbrow5_col3 {
#
#                 background-color:  #4295c3;
#
#             }
#
#             #T_91f44c68_4470_11e6_aa9a_f0def1ce0ecbrow5_col4 {
#
#                 background-color:  #0567a2;
#
#             }
#
#             #T_91f44c68_4470_11e6_aa9a_f0def1ce0ecbrow5_col5 {
#
#                 background-color:  #fff7fb;
#
#             }
#
#             #T_91f44c68_4470_11e6_aa9a_f0def1ce0ecbrow5_col6 {
#
#                 background-color:  #0567a2;
#
#             }
#
#             #T_91f44c68_4470_11e6_aa9a_f0def1ce0ecbrow6_col0 {
#
#                 background-color:  #fff7fb;
#
#             }
#
#             #T_91f44c68_4470_11e6_aa9a_f0def1ce0ecbrow6_col1 {
#
#                 background-color:  #4295c3;
#
#             }
#
#             #T_91f44c68_4470_11e6_aa9a_f0def1ce0ecbrow6_col2 {
#
#                 background-color:  #9cb9d9;
#
#             }
#
#             #T_91f44c68_4470_11e6_aa9a_f0def1ce0ecbrow6_col3 {
#
#                 background-color:  #dbdaeb;
#
#             }
#
#             #T_91f44c68_4470_11e6_aa9a_f0def1ce0ecbrow6_col4 {
#
#                 background-color:  #dbdaeb;
#
#             }
#
#             #T_91f44c68_4470_11e6_aa9a_f0def1ce0ecbrow6_col5 {
#
#                 background-color:  #4295c3;
#
#             }
#
#             #T_91f44c68_4470_11e6_aa9a_f0def1ce0ecbrow6_col6 {
#
#                 background-color:  #fff7fb;
#
#             }
#
#         </style>
#
#         <table id="T_91f44c68_4470_11e6_aa9a_f0def1ce0ecb" None>
#
#
#         <thead>
#
#             <tr>
#
#                 <th class="blank">
#
#                 <th class="col_heading level0 col0">Sami
#
#                 <th c

# %% [markdown]
# Nyt voin etsiä nimeni pystysarakkeesta ja näen riveistä, kenen musiikkimaku on lähimpänä minua. Rivitasolla näen, kuinka mones olen muiden raatilaisten sijoituslistalla. Parhaimmillaan musiikkimakuni on kolmanneksi lähimpänä toisia raatilaisia.
#
# Taulukosta nähdään, että Joen musiikkimaku on lähimpänä useimpia raatilaisia, sillä hänellä on eniten 1-sijoituksia. Poikkeuksellisin musiikkimaku on Artulla, joka on kauimpana useimpia raatilaisia.
#
# Tasapaksuja arvosanoja jakava Joe on lähempänä muita raatilaisia kuin ääripään arvosanoja jakava Arttu. Tämä johtuu euklidisen mittaustavasta, jossa erotusten summa korotetaan neliöön: yksi iso ero voi rangaista enemmän kuin monta pientä.

# %% [markdown]
# ## Samankaltaisuuden arviointi kuvaajasta

# %% [markdown]
# Kokeilen vielä euklidisen mittauksen lisäksi toista tapaa etsiä musiikkimaultaan lähin raatilainen. Sijoitan raatilaiset pisteinä kolmiulotteiseen kuvaajaan, josta etäisyyden voi arvioida silmämääräisesti. Tällä hetkellä yhdellä raatilaisella on 10 kappaletta tai ominaisuutta, jotka joudun typistämään kolmeksi. Tarkoitukseni on niputtaa kymmenen tasoa kolmeksi tasoksi siten, että mahdollisimman vähän tietoa menisi hukkaan.
#
# ### Pääkomponenttianalyysi
#
# Vähennän dimensioita pääkomponenttianalyysillä, joka etsii tasoja, joiden varianssi on mahdollisimman suuri. Toisin sanoen pääkomponenttianalyysi pyrkii keksimään ne tasot, jotka ovat kaikkein ilmaisuvoimaisimpia.

# %%
from IPython.display import YouTubeVideo
YouTubeVideo("_UVHneBUBW0")

# %%
# Käytän SciKit Learnin funktiota PCA, joka osaa redusoida dimensioita
from sklearn.decomposition import PCA
pca = PCA(n_components=3)
X = pca.fit_transform(df_norm.T)

# %%
# Piirrän kolmiulotteisen kuvaajan Matplotlib-kirjastolla
import matplotlib.pyplot as plt
from mpl_toolkits.mplot3d import Axes3D

fig = plt.figure(figsize=(12,10))
ax = fig.add_subplot(111, projection='3d')

# Lisään kuvaajan redusoidut dimensiot
ax.scatter(X[:,0], X[:,1], X[:,2])

# Nimeän pisteet raatilaisten mukaan
for i, name in enumerate(df_norm.columns):
    ax.text(X[i,0], X[i,1], X[i,2], name)

# Hyvä kuvakulma
ax.azim = 135
